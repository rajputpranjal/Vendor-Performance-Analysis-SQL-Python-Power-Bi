# %%
import pandas as pd

# %%
# import pandas as pd

# Read CSV file
data = pd.read_csv(r"C:\Users\pranj\Downloads\data\data\sales.csv")

# Show first 5 rows
# print(data.head())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12825363 entries, 0 to 12825362
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   InventoryId     object
#  1   Store           int64
#  2   Brand           int64
#  3   Description     object
#  4   Size            object
#  5   SalesQuantity   int64
#  6   SalesDollars    float64
#  7   SalesPrice      float64
#  8   SalesDate       object
#  9   Volume          float64
#  10  Classification  int64
#  11  ExciseTax       float64
#  12  VendorNo        int64
#  13  VendorName      object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 1.3+ GB

# %%
data.describe()
# Out:
#               Store         Brand  SalesQuantity  SalesDollars    SalesPrice  \
# count  1.282536e+07  1.282536e+07   1.282536e+07  1.282536e+07  1.282536e+07
# mean   4.389572e+01  1.215460e+04   2.566623e+00  3.524758e+01  1.569027e+01
# std    2.353947e+01  1.236843e+04   4.551810e+00  8.835689e+01  1.512728e+01
# min    1.000000e+00  5.800000e+01   1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.300000e+01  3.663000e+03   1.000000e+00  1.099000e+01  8.990000e+00
# 50%    4.700000e+01  6.349000e+03   1.000000e+00  1.899000e+01  1.299000e+01
# 75%    6.600000e+01  1.795400e+04   2.000000e+00  3.499000e+01  1.899000e+01
# max    8.100000e+01  9.063100e+04   1.231000e+03  2.606114e+04  5.799990e+03
#
#              Volume  Classification     ExciseTax      VendorNo
# count  1.282536e+07    1.282536e+07  1.282536e+07  1.282536e+07
# mean   9.394389e+02    1.413892e+00  1.479431e+00  7.125907e+03
# std    6.993202e+02    4.925295e-01  4.736633e+00  8.742565e+03
# ...

# %%
data.to_csv('sales.csv',index=False)

# %%
print(data)
# Out:
#                   InventoryId  Store  Brand                 Description  \
# 0         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4         1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ...                       ...    ...    ...                         ...
# 12825358      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825359      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825360      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825361      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825362      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
#
#                 Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  \
# ...

# %%
data
# Out:
#                   InventoryId  Store  Brand                 Description  \
# 0         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4         1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ...                       ...    ...    ...                         ...
# 12825358      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825359      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825360      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825361      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825362      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
#
#                 Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  \
# ...

# %%
data.head()
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# 4              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
# data = pd.read_csv("sales.csv")

# %%
data.to_csv("sales.csv",index=False)

# %%
import os 
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'sales.csv', 'Untitled.ipynb']

# %%
print(data.shape)
# Out:
# (5543, 10)

# %%
data.sample(5)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 953           7154  PREMIER DISTRIBUTORS         2024-03-12      9092
# 1024         90011  FORTUNE WINE BROKERS LLC     2024-03-21      9137
# 1953          6359  OLE SMOKY DISTILLERY LLC     2024-05-23     10045
# 1914          1485  CASTLE BRANDS CORP.          2024-05-17     10081
# 2526          1485  CASTLE BRANDS CORP.          2024-07-05     10715
#
#           PODate     PayDate  Quantity   Dollars  Freight Approval
# 953   2024-02-25  2024-04-13       125   1909.36    10.12      NaN
# 1024  2024-02-29  2024-04-25        34    246.92     1.33      NaN
# 1953  2024-05-02  2024-06-16       112   1035.37     5.07      NaN
# 1914  2024-05-05  2024-06-18      1725  26578.90   127.58      NaN
# 2526  2024-06-17  2024-08-06      1766  27531.69   129.40      NaN

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\pranj\Downloads\data\data\begin_inventory.csv")

# %%
data.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01

# %%
data.to_csv("begin_inventory.csv", index=False)

# %%
import os 
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'begin_inventory.csv', 'end_inventory.csv', 'sales.csv', 'Untitled.ipynb']

# %%
print(data.shape)
# Out:
# (206529, 9)

# %%
data.sample(4)
# Out:
#                  InventoryId  Store         City  Brand  \
# 33574      14_BROMWICH_21320     14     BROMWICH  21320
# 142992  59_CLAETHORPES_22079     59  CLAETHORPES  22079
# 198265    76_DONCASTER_23948     76    DONCASTER  23948
# 88490    37_PAETHSMOUTH_6498     37  PAETHSMOUTH   6498
#
#                          Description   Size  onHand  Price   startDate
# 33574             Zion Dolev Muscato  750mL      10  10.99  2024-01-01
# 142992  C Y Toro Casa Diblo Cab Svgn  750mL      44   9.99  2024-01-01
# 198265       Ch La Croix Lartigue 09  750mL      37  38.99  2024-01-01
# 88490    Franzia Chablis Old World C     5L       8  16.99  2024-01-01

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\pranj\Data

# %%
print(data)
# Out:
#                InventoryId  Store          City  Brand  \
# 0        1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1        1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2        1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3        1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4        1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ...                    ...    ...           ...    ...
# 206524  79_BALLYMENA_46985     79     BALLYMENA  46985
# 206525  79_BALLYMENA_47014     79     BALLYMENA  47014
# 206526  79_BALLYMENA_47090     79     BALLYMENA  47090
# 206527  79_BALLYMENA_90011     79     BALLYMENA  90011
# 206528  79_BALLYMENA_90089     79     BALLYMENA  90089
#
#                          Description   Size  onHand   Price   startDate
# 0        Gekkeikan Black & Gold Sake  750mL       8   12.99  2024-01-01
# 1             Canadian Club 1858 VAP  750mL       7   10.99  2024-01-01
# 2           Herradura Silver Tequila  750mL       6   36.99  2024-01-01
# ...

# %%
data
# Out:
#                InventoryId  Store          City  Brand  \
# 0        1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1        1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2        1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3        1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4        1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ...                    ...    ...           ...    ...
# 206524  79_BALLYMENA_46985     79     BALLYMENA  46985
# 206525  79_BALLYMENA_47014     79     BALLYMENA  47014
# 206526  79_BALLYMENA_47090     79     BALLYMENA  47090
# 206527  79_BALLYMENA_90011     79     BALLYMENA  90011
# 206528  79_BALLYMENA_90089     79     BALLYMENA  90089
#
#                          Description   Size  onHand   Price   startDate
# 0        Gekkeikan Black & Gold Sake  750mL       8   12.99  2024-01-01
# 1             Canadian Club 1858 VAP  750mL       7   10.99  2024-01-01
# 2           Herradura Silver Tequila  750mL       6   36.99  2024-01-01
# ...

# %%
import pandas as pd

# %%
data =pd.read_csv(r"C:\Users\pranj\Downloads\data\data\purchase_prices.csv")

# %%
data.head()
# Out:
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.28          8320  SHAW ROSS INT L IMP LTD
# 1          28.67          1128  BROWN-FORMAN CORP
# 2          30.46          1128  BROWN-FORMAN CORP
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4          10.94          7245  PROXIMO SPIRITS INC.

# %%
data.to_csv("purchase_prices.csv",index = False)

# %%
import os 
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'begin_inventory.csv', 'end_inventory.csv', 'purchases.csv', 'purchase_prices.csv', 'sales.csv', 'Untitled.ipynb']

# %%
data = pd.read_csv(r"C:\Users\pranj\Downloads\data\data\purchases.csv")

# %%
data.to_csv("purchases.csv",index= False)

# %%
import pandas as pd # pandas import step 1

# %%
data = pd.read_csv(r"C:\Users\pranj\Downloads\data\data\vendor_invoice.csv")  #read file

# %%
data.to_csv("vendor_invoice.csv", index = False)  #load file

# %%
data.head()   # show data
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47      NaN
# 1  2023-12-22  2024-02-21        15     140.55     8.57      NaN
# 2  2023-12-24  2024-02-16         5     106.60     4.61      NaN
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20      NaN
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20      NaN

# %%
import os   # list of file name in folder
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'begin_inventory.csv', 'end_inventory.csv', 'purchases.csv', 'purchase_prices.csv', 'sales.csv', 'Untitled.ipynb', 'vendor_invoice.csv']

# %%
print(data.shape)  # show the file in row and cloum values
# Out:
# (5543, 10)

# %%
data   # all data shows
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0              105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1             4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2              388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3              480  BACARDI USA INC              2024-01-12      8106
# 4              516  BANFI PRODUCTS CORP          2024-01-07      8170
# ...            ...                          ...         ...       ...
# 5538          9622  WEIN BAUER INC               2025-01-06     13626
# 5539          9625  WESTERN SPIRITS BEVERAGE CO  2025-01-10     13661
# 5540          3664  WILLIAM GRANT & SONS INC     2025-01-02     13643
# 5541          9815  WINE GROUP INC               2025-01-03     13602
# 5542         90058  ZORVINO VINEYARDS            2025-01-05     13574
#
#           PODate     PayDate  Quantity    Dollars  Freight Approval
# ...

# %%
data.sample(2)   #shows 2 line random data
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 5454          2242  DELICATO VINEYARDS INC       2025-01-10     13554
# 447           7255                   PSP WINES   2024-02-05      8541
#
#           PODate     PayDate  Quantity   Dollars  Freight Approval
# 5454  2024-12-18  2025-02-03      5210  45684.82   237.56      NaN
# 447   2024-01-19  2024-03-06       416   3247.06    17.21      NaN

# %%
data.head(2) #first 2 line shows
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6   214.26     3.47      NaN
# 1  2023-12-22  2024-02-21        15   140.55     8.57      NaN

# %%
import pandas as pd 
import os 
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///inventory.db")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 6
#       2 import pandas as pd
#       4 folder = "data"
# ----> 6 for file in os.listdir(folder):
#       7     if file.endswith('.csv'):
#       8         path = os.path.join(folder, file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\pranj\Data

# %%
import os 
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'begin_inventory.csv', 'end_inventory.csv', 'Exploratory data analysis.ipynb', 'get_vendor_summary.py', 'ingestion_db.py', 'inventory.db', 'logs', 'purchases.csv', 'purchase_prices.csv', 'sales.csv', 'Untitled.ipynb', 'vendor_invoice.csv', '__pycache__']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\pranj\\Data'

# %%
print (os.listdir())
# Out:
# ['.ipynb_checkpoints', 'begin_inventory.csv', 'end_inventory.csv', 'Exploratory data analysis.ipynb', 'get_vendor_summary.py', 'ingestion_db.py', 'inventory.db', 'logs', 'purchases.csv', 'purchase_prices.csv', 'sales.csv', 'Untitled.ipynb', 'vendor_invoice.csv', '__pycache__']

# %%
folder = "C:\Users\pranj\Downloads\data\data"

# r"C:\\Users\\pranj\\Data"

# %%
for file in os.listdir(folder):
    if file.endswith('.csv'):
        path = os.path.join(folder, file)
        df = pd.read_csv(path)
        print(file, df.shape)
        ingest_db(df,file[:-4], engine)
# Out:
# begin_inventory.csv (206529, 9)
# end_inventory.csv (224489, 9)
# purchases.csv (2372474, 16)
# purchase_prices.csv (12261, 9)
# sales.csv (12825363, 14)
# vendor_invoice.csv (5543, 11)

# %%
def ingest_db(df, table_name, engine):
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

# %%
# Scipt
import pandas as pd 
import os 
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename = "logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
)

# %%
def load_raw_data(folder):
    ''' this function is load the csv as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir(folder):
        if file.endswith('.csv'):
           path = os.path.join(folder, file)
           df = pd.read_csv(path)
           logging.info(f'ingesting {file} in db')
           ingest_db(df,file[:-4], engine)
         
        end = time.time()
        total_time = (end - start)/60
        logging.info('-------ingestion complete---------')
        
        logging.info(f'total time taken:{total_time} minutes')

# %%
def ingest_db(df, table_name, engine):
    ''' this function will ingest dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

# %%
import pandas as pd 
import os 
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename = "logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
)

engine = create_engine("sqlite:///inventory.db")
def ingest_db(df, table_name, engine):
    ''' this function will ingest dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

def load_raw_data(folder):
    ''' this function is load the csv as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir(folder):
        if file.endswith('.csv'):
           path = os.path.join(folder, file)
           df = pd.read_csv(path)
           logging.info(f'ingesting {file} in db')
           ingest_db(df,file[:-4], engine)
         
    end = time.time()
    total_time = (end - start)/60
    logging.info('-------ingestion complete---------')
        
    logging.info(f'total time taken:{total_time} minutes')

if __name__ == "__main__":
    folder = r"C:\Users\pranj\Downloads\data\data" 
    load_raw_data(folder)

# %%
import os
print(os.path.exists(folder))
# Out:
# True

# %%
import os

folder = r"C:\Users\pranj\Downloads\data\data" 

print(os.path.exists(folder))
# Out:
# True
