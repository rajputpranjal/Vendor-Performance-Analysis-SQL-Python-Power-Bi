# %%
# Exploratory data analaysis

# understanding the dataset to explore the data in present in the data and if there is a need of creating some aggregated table that can help with :
# vendor selection for profitability 
# product pricing operation

# %%
import pandas as pd
import sqlite3

# %%
# creating database connection
conn = sqlite3.connect('inventory.db')

# %%
# checking tables present in the database
tables = pd.read_sql_query("SELECT name  from sqlite_master WHERE type ='table'",conn)
tables
# Out:
#                     name
# 0  vendor_salary_summary
# 1         vendor_invoice
# 2   vendor_sales_summary
# 3        begin_inventory
# 4          end_inventory
# 5              purchases
# 6        purchase_prices
# 7                  sales

# %%
pd.read_sql("select count(*) from purchases ", conn)
# Out:
#    count(*)
# 0   2372474

# %%
for table in tables['name']:
    print('_'*50,f'{table}','_'*50)
    print('count of records:', pd.read_sql(f"select count(*) as count from {table}",conn)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 5", conn))
# Out:
# __________________________________________________ vendor_salary_summary __________________________________________________
# count of records: 10692
#    VendorNumber                   VendorName  Brand              Description  \
# 0          1128  BROWN-FORMAN CORP             1233  Jack Daniels No 7 Black
# 1          4425        MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035  PERNOD RICARD USA             8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC      4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC      3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99   1750                 145080
# 1          23.19        28.99   1750                 164038
# 2          18.24        24.99   1750                 187407
# 3          16.17        22.99   1750                 201682
# ...

# %%
vendor_invoice = pd.read_sql_query("select * from vendor_invoice where VendorNumber= 4466",conn)
vendor_invoice
# Out:
#     Unnamed: 0  VendorNumber                   VendorName InvoiceDate  \
# 0            1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07
# 1           90          4466  AMERICAN VINTAGE BEVERAGE    2024-01-19
# 2          189          4466  AMERICAN VINTAGE BEVERAGE    2024-01-18
# 3          284          4466  AMERICAN VINTAGE BEVERAGE    2024-01-27
# 4          380          4466  AMERICAN VINTAGE BEVERAGE    2024-02-04
# 5          486          4466  AMERICAN VINTAGE BEVERAGE    2024-02-09
# 6          586          4466  AMERICAN VINTAGE BEVERAGE    2024-02-17
# 7          691          4466  AMERICAN VINTAGE BEVERAGE    2024-03-01
# 8          798          4466  AMERICAN VINTAGE BEVERAGE    2024-03-07
# 9          899          4466  AMERICAN VINTAGE BEVERAGE    2024-03-12
# 10         995          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16
# 11        1096          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23
# ...

# %%
purchase_prices = pd.read_sql_query("select * from purchase_prices where VendorNumber= 4466",conn)
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
purchases = pd.read_sql_query("select * from purchases where VendorNumber= 4466",conn)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
sales = pd.read_sql_query("select * from sales where VendorNo= 4466",conn)
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     9_BLACKPOOL_5215      9   5215  TGI Fridays Long Island Iced  1.75L
# 9449     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
vendor_invoice= pd.read_sql_query("select * from vendor_invoice where VendorNumber	= 4466",conn)
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
vendor_invoice['PONumber'].nunique()
# Out:
# 55

# %%
vendor_invoice.columns
# Out:
# Index(['Unnamed: 0', 'VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber',
#        'PODate', 'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
sales.groupby('Brand')[['SalesQuantity',	'SalesDollars',	'SalesPrice']].sum()

# %%
vendor_invoice.columns
# Out:
# Index(['Unnamed: 0', 'VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber',
#        'PODate', 'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""select VendorNumber, SUM(Freight) as FreightCost from vendor_invoice group by VendorNumber""",conn)

# %%
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0               2        27.08
# 1              54         0.48
# 2              60       367.52
# 3             105        62.39
# 4             200         6.19
# ..            ...          ...
# 121         98450       856.02
# 122         99166       130.09
# 123        172662       178.34
# 124        173357       202.50
# 125        201359         0.09
#
# [126 rows x 2 columns]

# %%
vendor_invoice.columns
# Out:
# Index(['Unnamed: 0', 'VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber',
#        'PODate', 'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""select 
p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.price as ActualPrice,
pp.volume,
sum(Quantity) as TotalPurchaseQuantity,
sum(Dollars) as TotalPurchaseDollars
FROM purchases P
JOIN purchase_prices PP
ON p.Brand = PP.Brand
where p.PurchasePrice > 0
GROUP BY p.VendorNumber,p.VendorName, p.Brand
ORDER BY TotalPurchaseDollars""",conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74
# 3              8004  SAZERAC CO INC                5683           0.39
# 4              9815  WINE GROUP INC                8527           1.32
# ...             ...                          ...    ...            ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17
# 10689         17035  PERNOD RICARD USA             8068          18.24
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19
# 10691          1128  BROWN-FORMAN CORP             1233          26.27
#
#        ActualPrice Volume  TotalPurchaseQuantity  TotalPurchaseDollars
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT VendorNo,
Brand,
SUM(SalesDollars) as TotalSalesDollars,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(SalesPrice) as TotalSalesPrice,
SUM(ExciseTax) as TotalExcieseTax 
from sales

Group by VendorNo,Brand
ORDER BY TotalSalesDollars""",conn)
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesQuantity  \
# 0          8004   5287               0.98                   2
# 1          9206   2773               0.99                   1
# 2          3252   3933               1.98                   2
# 3          3924   9123               1.98                   2
# 4         10050   3623               1.98                   2
# ...         ...    ...                ...                 ...
# 11267      3960   3545         4223107.62              135838
# 11268      3960   4261         4475972.88              200412
# 11269     17035   8068         4538120.60              187140
# 11270      4425   3405         4819073.49              160247
# 11271      1128   1233         5101919.51              142049
#
#        TotalSalesPrice  TotalExcieseTax
# 0                 0.98             0.10
# 1                 0.99             0.05
# 2                 0.99             0.10
# 3                 0.99             0.10
# ...

# %%
# not Ountput Show in this Query becoz more time to load 

import time 
start = time.time()
final_table=pd.read_sql_query("""SELECT 
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC
""", conn)
end = time.time()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\OneDrive\Documents\Anaconda\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: no such table: PurchaseSummary
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[41], line 3
#       1 import time
#       2 start = time.time()
# ----> 3 final_table=pd.read_sql_query("""SELECT
#       4     ps.VendorNumber,
#       5     ps.VendorName,
#       6     ps.Brand,
#       7     ps.Description,
#       8     ps.PurchasePrice,
#       9     ps.ActualPrice,
#      10     ps.Volume,
#      11     ps.TotalPurchaseQuantity,
#      12     ps.TotalPurchaseDollars,
# ...

# %%
# This Is Query Optimization In Query 
# short Query Merge in One Short Query optimization 
# Optimize Way
# Seprate Query are seprate column Shows the Query Optimze
vendor_salary_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

PurchaseSummary AS (
    SELECT 
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price AS ActualPrice,
        pp.Volume,
        SUM(Quantity) AS TotalPurchaseQuantity,
        SUM(Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY 
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price,
        pp.Volume
),

SalesSummary AS (
    SELECT 
        VendorNo,
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT 
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC
""", conn)

# %%
# Aggregate Table
# main table create aggreate this data to load and transfor thas work on data analyst 
vendor_salary_summary

# %%
vendor_salary_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesDollars        float64
# TotalSalesQuantity       float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_salary_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesDollars        178
# TotalSalesQuantity       178
# TotalSalesPrice          178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_salary_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP', 'MARTIGNETTI COMPANIES', 'PERNOD RICARD USA',
#        'DIAGEO NORTH AMERICA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'MAJESTIC FINE WINES',
#        'ULTRA BEVERAGE COMPANY LLP', 'STOLI GROUP,(USA) LLC',
#        'PROXIMO SPIRITS INC.', 'MOET HENNESSY USA INC', 'CAMPARI AMERICA',
#        'SAZERAC CO INC', 'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'SAZERAC NORTH AMERICA INC.', 'PALM BAY INTERNATIONAL INC',
#        'REMY COINTREAU USA INC', 'SIDNEY FRANK IMPORTING CO',
#        'E & J GALLO WINERY', 'WILLIAM GRANT & SONS INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'EDRINGTON AMERICAS', 'CASTLE BRANDS CORP.',
#        'SOUTHERN WINE & SPIRITS NE', 'STE MICHELLE WINE ESTATES',
#        'TRINCHERO FAMILY ESTATES', 'MHW LTD', 'WINE GROUP INC',
#        'PERFECTA WINES', 'LUXCO INC', 'TREASURY WINE ESTATES',
#        'DIAGEO CHATEAU ESTATE WINES', 'SHAW ROSS INT L IMP LTD',
# ...

# %%
vendor_salary_summary['Description'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vendor_salary_summary['Description'].unique()
#
# NameError: name 'vendor_salary_summary' is not defined

# %%
vendor_salary_summary['Volume'] = vendor_salary_summary['Volume'].astype('float64')

# %%
vendor_salary_summary.fillna(0, inplace = True)

# %%
vendor_salary_summary['VendorName'] = vendor_salary_summary['VendorName'].str.strip()

# %%
vendor_salary_summary['GrossProfit'] = vendor_salary_summary['TotalSalesDollars'] - vendor_salary_summary['TotalPurchaseDollars']

# %%
vendor_salary_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 vendor_salary_summary
#
# NameError: name 'vendor_salary_summary' is not defined

# %%
vendor_salary_summary['GrossProfit'].min()
# Out:
# -52002.780000000006

# %%
vendor_salary_summary['ProfitMargin'] = vendor_salary_summary['GrossProfit'] / vendor_salary_summary['TotalSalesDollars']*100

# %%
vendor_salary_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'ActualPrice', 'Volume', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesDollars', 'TotalSalesQuantity',
#        'TotalSalesPrice', 'TotalExciseTax', 'FreightCost', 'GrossProfit',
#        'ProfitMargin'],
#       dtype='object')

# %%
# Drop column 

vendor_salary_summary.drop('ProfitMargine', axis=1, inplace=True)

# %%
vendor_salary_summary['StackTurnover'] = vendor_salary_summary['TotalSalesQuantity']/vendor_salary_summary['TotalPurchaseQuantity']

# %%
vendor_salary_summary['SalestoPurchaseRatio'] = vendor_salary_summary['TotalSalesDollars']/vendor_salary_summary['TotalPurchaseDollars']

# %%
vendor_salary_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'ActualPrice', 'Volume', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesDollars', 'TotalSalesQuantity',
#        'TotalSalesPrice', 'TotalExciseTax', 'FreightCost'],
#       dtype='object')

# %%
vendor_salary_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                   float64
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesDollars        float64
# TotalSalesQuantity       float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# GrossProfit              float64
# ProfitMargin             float64
# StackTurnover            float64
# SalestoPurchaseRatio     float64
# dtype: object

# %%
cursor = conn.cursor()

# %%
cursor.execute(""" Create table vendor_sales_summary (
VendorNumber int,
VendorName varchar(100),
Brand int,
Description varchar(100),
PurchasePrice decimal(10,2),
       ActualPrice decimal(10,2),
       Volume ,
       TotalPurchaseQuantity int,
       
       TotalPurchaseDollars decimal(15,2),
       TotalSalesDollars decimal(15,2),
       TotalSalesQuantity int,
       TotalSalesPrice decimal(15,2), 
       TotalExciseTax decimal(15,2),
       FreightCost decimal(15,2),
       GrossProfit decimal(15,2),
       ProfitMargin decimal(15,2),
       StackTurnover decimal(15,2),
       SalestoPurchaseRatio decimal(15,2),
       primary key (Vendornumber, Brand)
       );
       """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 cursor.execute(""" Create table vendor_sales_summary (
#       2 VendorNumber int,
#       3 VendorName varchar(100),
#       4 Brand int,
#       5 Description varchar(100),
#       6 PurchasePrice decimal(10,2),
#       7        ActualPrice decimal(10,2),
#       8        Volume ,
#       9        TotalPurchaseQuantity int,
#      10
#      11        TotalPurchaseDollars decimal(15,2),
#      12        TotalSalesDollars decimal(15,2),
#      13        TotalSalesQuantity int,
#      14        TotalSalesPrice decimal(15,2),
#      15        TotalExciseTax decimal(15,2),
#      16        FreightCost decimal(15,2),
#      17        GrossProfit decimal(15,2),
#      18        ProfitMargin decimal(15,2),
#      19        StackTurnover decimal(15,2),
#      20        SalestoPurchaseRatio decimal(15,2),
# ...

# %%
pd.read_sql_query("select * from vendor_sales_summary",conn)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, ActualPrice, Volume, TotalPurchaseQuantity, TotalPurchaseDollars, TotalSalesDollars, TotalSalesQuantity, TotalSalesPrice, TotalExciseTax, FreightCost, GrossProfit, ProfitMargin, StackTurnover, SalestoPurchaseRatio]
# Index: []

# %%
vendor_salary_summary.to_sql(
    'vendor_salary_summary',
    conn,
    if_exists='replace',
    index=False
)

# %%
import pandas as pd
import sqlite3
import logging
from sqlalchemy import create_engine
from ingestion_db import ingest_db
import ingestion_db
import importlib

importlib.reload(ingestion_db)
logging.basicConfig(
    filename="logs/ingestion_db.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_vendor_summary(conn):
    """Merge tables and create vendor summary"""

    vendor_sales_summary = pd.read_sql_query("""
    WITH FreightSummary AS (
        SELECT VendorNumber,
               SUM(Freight) AS FreightCost
        FROM vendor_invoice
        GROUP BY VendorNumber
    ),

    PurchaseSummary AS (
        SELECT 
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(Quantity) AS TotalPurchaseQuantity,
            SUM(Dollars) AS TotalPurchaseDollars
        FROM purchases p
        JOIN purchase_prices pp
            ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
        GROUP BY 
            p.VendorNumber,
            p.VendorName,
            p.Brand,
            p.Description,
            p.PurchasePrice,
            pp.Price,
            pp.Volume
    ),

    SalesSummary AS (
        SELECT 
            VendorNo,
            Brand,
            SUM(SalesDollars) AS TotalSalesDollars,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNo, Brand
    )

    SELECT 
        ps.VendorNumber,
        ps.VendorName,
        ps.Brand,
        ps.Description,
        ps.PurchasePrice,
        ps.ActualPrice,
        ps.Volume,
        ps.TotalPurchaseQuantity,
        ps.TotalPurchaseDollars,
        ss.TotalSalesDollars,
        ss.TotalSalesQuantity,
        ss.TotalSalesPrice,
        ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss
        ON ps.VendorNumber = ss.VendorNo
        AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs
        ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseDollars DESC
    """, conn)

    return vendor_sales_summary


def clean_data(df):
    """Clean dataframe"""

    df['Volume'] = df['Volume'].astype('float64')
    df.fillna(0, inplace=True)

    df['VendorName'] = df['VendorName'].str.strip()
    df['Description'] = df['Description'].str.strip()

    df['GrossProfit'] = df['TotalSalesDollars'] - df['TotalPurchaseDollars']
    df['ProfitMargin'] = df['GrossProfit'] / df['TotalSalesDollars'] * 100
    df['StockTurnover'] = df['TotalSalesQuantity'] / df['TotalPurchaseQuantity']
    df['SalesToPurchaseRatio'] = df['TotalSalesDollars'] / df['TotalPurchaseDollars']

    return df


if __name__ == "__main__":

    folder = r"C:\Users\pranj\Downloads\data\data" 

    ingestion_db.load_raw_data(folder)

    engine = create_engine("sqlite:///inventory.db")

    logging.info('creating vendor summary table....')
    summary_df = create_vendor_summary(engine.connect())

    logging.info('cleaning data....')
    clean_df = clean_data(summary_df)

    logging.info('insert data....')
    ingest_db(clean_df, "vendor_sales_summary", engine)

    logging.info('completed')

# %%
folder = r"C:\Users\pranj\Downloads\data\data"

load_raw_data(folder)

# %%
import ingestion_db
import importlib

importlib.reload(ingestion_db)
# Out:
# <module 'ingestion_db' from 'C:\\Users\\pranj\\Data\\ingestion_db.py'>

# %%
folder = r"C:\Users\pranj\Downloads\data\data"

ingestion_db.load_raw_data(folder)

# %%
df = pd.read_sql("SELECT * FROM vendor_sales_summary LIMIT 5", conn)

print(df)

# %%
with engine.connect() as conn:
    summary_df = create_vendor_summary(conn)

print(summary_df.head())

# %%
print(clean_df.shape)

# %%
import sqlite3

conn = sqlite3.connect("inventory.db")

query = "SELECT name FROM sqlite_master WHERE type='table';"

tables = pd.read_sql(query, conn)

print(tables)

# %%
df = pd.read_sql("SELECT * FROM vendor_sales_summary LIMIT 5", conn)

print(df)

# %%
print(summary_df.head())

# %%
inventory.db

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("inventory.db")

df = pd.read_sql(
    "SELECT * FROM vendor_sales_summary LIMIT 10",
    conn
)

print(df)

# %%
tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)

print(tables)

# %%
print(df.shape)
